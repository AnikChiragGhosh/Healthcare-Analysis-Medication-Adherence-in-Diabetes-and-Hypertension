# %%
import pandas as pd

# %%
diabetes = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Desktop\healthcare\Diabetes Adherence Data.csv')

# %%
diabetes
# Out:
#          MEMBER  INO          PZTIQNT NZXQ  ADHERENCE GENDER  PRACTICE NO  \
# 0      98788489    0  XS TZFZDZWZ NYZPIXBI          2      F       860662
# 1      98795328    0  XR TSITSIKZYI XUDOTI          7      M       877344
# 2      98795328    0  XR TSITSIKZYI XUDOTI          7      M       877344
# 3      98795328    0  XR TSITSIKZYI XUDOTI          7      M       877344
# 4      98795328    0  XR TSITSIKZYI XUDOTI          7      M       877344
# ...         ...  ...                   ...        ...    ...          ...
# 52611  94225589    2     XS QSTQR CHZXBZTI          7      F       877336
# 52612  94225769    4       XR DZVID XOZHYI          6      M       863181
# 52613  94225829    7  XRS SIKULILQ XTQXQRI          5      M       944955
# 52614  94225829    7  XRS SIKULILQ XTQXQRI          5      M       944955
# 52615  94226748    0     XRS JZNQ ZINYONGO          1      M       862118
#
#        DIS                           PROVIDER           AS AT NETWORKS  \
# ...

# %%
htn = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Desktop\healthcare\HTN Adherence Data.csv')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\367580687.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   htn = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Desktop\healthcare\HTN Adherence Data.csv')

# %%
htn
# Out:
#           MEMBER  INO            PZTIQNT NZXQ  ADHERENCE GENDER  PRACTICE NO  \
# 0       98785554    0        XR TZPIWZ GOTORZ          1      M       877395
# 1       98785678    0        XS XQRCY XUTQPFZ          6      F       877344
# 2       98785678    0        XS XQRCY XUTQPFZ          6      F       877344
# 3       98785678    0        XS XQRCY XUTQPFZ          6      F       877344
# 4       98785678    0        XS XQRCY XUTQPFZ          6      F       877344
# ...          ...  ...                     ...        ...    ...          ...
# 218811  94866843    1     XR DOXINIC CHIGQRWQ          1      M       849685
# 218812  94866843    4      XS THQRQSZ CHIVQRO          1      F       965804
# 218813  94898975    0      XR OSCZR XZNJQNGWZ          1      M       877360
# 218814  94898299    0    XS QTHQL CHITINDINGU         10      F       877395
# 218815  94898299    1  XRS PHQONZ CHITINDINGU          1      M       877395
#
# ...

# %%
diabetes.columns
# Out:
# Index(['MEMBER', 'INO', 'PZTIQNT NZXQ', 'ADHERENCE', 'GENDER', 'PRACTICE NO',
#        'DIS', 'PROVIDER', 'AS AT NETWORKS', 'REFERRING PRACTICE', 'PAYER NAME',
#        'INV REF', 'SERVICE DATE', 'ASSESS DATE', 'DATE RECEIVED', 'CLM CODE',
#        'CODE DESCRIPTION', 'UNITS', 'SCRIPT CODE', 'AMOUNT CLAIMED',
#        'PAID FROM RISK AMT', 'PAID FROM THRESHHOLD', 'PAID FROM SAVINGS',
#        'RECOVERY AMOUNT', 'TOTAL AMOUNT PAID', 'TARIFF', 'CO-PAY', 'PAY TO',
#        'REJ', 'REV', 'AUTH NO', 'DL', 'CLAIM NO', 'CLAIM LINE NO',
#        'DUPLICATE CLAIM', 'DUPLICATE CLAIM LINE', 'OPTION NAME', 'PAPER/EDI',
#        'ASSESSOR NAME', 'BIRTHDATE', 'CURRENT AGE'],
#       dtype='object')

# %%
# Creating a Unique identifier by concatenating 'MEMBER NO' and 'INO'
diabetes['BENEFICIARY'] = diabetes.MEMBER.astype(str) + diabetes.INO.astype(str)

# %%
htn['BENEFICIARY'] = htn.MEMBER.astype(str) + htn.INO.astype(str)

# %%
diabetes
# Out:
#          MEMBER  INO          PZTIQNT NZXQ  ADHERENCE GENDER  PRACTICE NO  \
# 0      98788489    0  XS TZFZDZWZ NYZPIXBI          2      F       860662
# 1      98795328    0  XR TSITSIKZYI XUDOTI          7      M       877344
# 2      98795328    0  XR TSITSIKZYI XUDOTI          7      M       877344
# 3      98795328    0  XR TSITSIKZYI XUDOTI          7      M       877344
# 4      98795328    0  XR TSITSIKZYI XUDOTI          7      M       877344
# ...         ...  ...                   ...        ...    ...          ...
# 52611  94225589    2     XS QSTQR CHZXBZTI          7      F       877336
# 52612  94225769    4       XR DZVID XOZHYI          6      M       863181
# 52613  94225829    7  XRS SIKULILQ XTQXQRI          5      M       944955
# 52614  94225829    7  XRS SIKULILQ XTQXQRI          5      M       944955
# 52615  94226748    0     XRS JZNQ ZINYONGO          1      M       862118
#
#        DIS                           PROVIDER           AS AT NETWORKS  \
# ...

# %%
htn
# Out:
#           MEMBER  INO            PZTIQNT NZXQ  ADHERENCE GENDER  PRACTICE NO  \
# 0       98785554    0        XR TZPIWZ GOTORZ          1      M       877395
# 1       98785678    0        XS XQRCY XUTQPFZ          6      F       877344
# 2       98785678    0        XS XQRCY XUTQPFZ          6      F       877344
# 3       98785678    0        XS XQRCY XUTQPFZ          6      F       877344
# 4       98785678    0        XS XQRCY XUTQPFZ          6      F       877344
# ...          ...  ...                     ...        ...    ...          ...
# 218811  94866843    1     XR DOXINIC CHIGQRWQ          1      M       849685
# 218812  94866843    4      XS THQRQSZ CHIVQRO          1      F       965804
# 218813  94898975    0      XR OSCZR XZNJQNGWZ          1      M       877360
# 218814  94898299    0    XS QTHQL CHITINDINGU         10      F       877395
# 218815  94898299    1  XRS PHQONZ CHITINDINGU          1      M       877395
#
# ...

# %%
diabetes.columns
# Out:
# Index(['MEMBER', 'INO', 'PZTIQNT NZXQ', 'ADHERENCE', 'GENDER', 'PRACTICE NO',
#        'DIS', 'PROVIDER', 'AS AT NETWORKS', 'REFERRING PRACTICE', 'PAYER NAME',
#        'INV REF', 'SERVICE DATE', 'ASSESS DATE', 'DATE RECEIVED', 'CLM CODE',
#        'CODE DESCRIPTION', 'UNITS', 'SCRIPT CODE', 'AMOUNT CLAIMED',
#        'PAID FROM RISK AMT', 'PAID FROM THRESHHOLD', 'PAID FROM SAVINGS',
#        'RECOVERY AMOUNT', 'TOTAL AMOUNT PAID', 'TARIFF', 'CO-PAY', 'PAY TO',
#        'REJ', 'REV', 'AUTH NO', 'DL', 'CLAIM NO', 'CLAIM LINE NO',
#        'DUPLICATE CLAIM', 'DUPLICATE CLAIM LINE', 'OPTION NAME', 'PAPER/EDI',
#        'ASSESSOR NAME', 'BIRTHDATE', 'CURRENT AGE', 'BENEFICIARY'],
#       dtype='object')

# %%
# Removing the unwanted columns or variables from the dataset
diabetes = diabetes[['BENEFICIARY', 'ADHERENCE', 'GENDER', 'UNITS','AMOUNT CLAIMED', 'OPTION NAME', 'CURRENT AGE']].copy()
htn = htn[['BENEFICIARY', 'ADHERENCE', 'GENDER', 'UNITS','AMOUNT CLAIMED', 'OPTION NAME', 'CURRENT AGE']].copy()

# %%
diabetes
# Out:
#       BENEFICIARY  ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0       987884890          2      F     30         6800.00
# 1       987953280          7      M     90         2654.98
# 2       987953280          7      M    120        40914.28
# 3       987953280          7      M    120        55643.20
# 4       987953280          7      M     90         3573.25
# ...           ...        ...    ...    ...             ...
# 52611   942255892          7      F      8        44522.39
# 52612   942257694          6      M     60        33792.00
# 52613   942258297          5      M     30          513.59
# 52614   942258297          5      M     30         1071.89
# 52615   942267480          1      M     99         3500.00
#
#                  OPTION NAME  CURRENT AGE
# 0          STUDYMATE PRIVATE           24
# 1                      ICARE           53
# 2                      ICARE           53
# 3                      ICARE           53
# ...

# %%
htn
# Out:
#        BENEFICIARY  ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0        987855540          1      M   30.0         1063.22
# 1        987856780          6      F   30.0         1358.89
# 2        987856780          6      F   30.0         1819.49
# 3        987856780          6      F   30.0          306.07
# 4        987856780          6      F   30.0         1654.99
# ...            ...        ...    ...    ...             ...
# 218811   948668431          1      M   30.0         3500.00
# 218812   948668434          1      F   30.0         4763.96
# 218813   948989750          1      M   30.0         3899.19
# 218814   948982990         10      F   30.0            4.13
# 218815   948982991          1      M   60.0         4638.34
#
#               OPTION NAME  CURRENT AGE
# 0       STUDYMATE PRIVATE           26
# 1       STUDYMATE PRIVATE           57
# 2       STUDYMATE PRIVATE           57
# 3       STUDYMATE PRIVATE           57
# 4       STUDYMATE PRIVATE           57
# ...

# %%
diabetes.rename(columns={"CURRENT AGE": "AGE"}, inplace=True)
htn.rename(columns={"CURRENT AGE": "AGE"}, inplace=True)

# %%
diabetes
# Out:
#       BENEFICIARY  ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0       987884890          2      F     30         6800.00
# 1       987953280          7      M     90         2654.98
# 2       987953280          7      M    120        40914.28
# 3       987953280          7      M    120        55643.20
# 4       987953280          7      M     90         3573.25
# ...           ...        ...    ...    ...             ...
# 52611   942255892          7      F      8        44522.39
# 52612   942257694          6      M     60        33792.00
# 52613   942258297          5      M     30          513.59
# 52614   942258297          5      M     30         1071.89
# 52615   942267480          1      M     99         3500.00
#
#                  OPTION NAME  AGE
# 0          STUDYMATE PRIVATE   24
# 1                      ICARE   53
# 2                      ICARE   53
# 3                      ICARE   53
# 4                      ICARE   53
# ...                      ...  ...
# ...

# %%
htn
# Out:
#        BENEFICIARY  ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0        987855540          1      M   30.0         1063.22
# 1        987856780          6      F   30.0         1358.89
# 2        987856780          6      F   30.0         1819.49
# 3        987856780          6      F   30.0          306.07
# 4        987856780          6      F   30.0         1654.99
# ...            ...        ...    ...    ...             ...
# 218811   948668431          1      M   30.0         3500.00
# 218812   948668434          1      F   30.0         4763.96
# 218813   948989750          1      M   30.0         3899.19
# 218814   948982990         10      F   30.0            4.13
# 218815   948982991          1      M   60.0         4638.34
#
#               OPTION NAME  AGE
# 0       STUDYMATE PRIVATE   26
# 1       STUDYMATE PRIVATE   57
# 2       STUDYMATE PRIVATE   57
# 3       STUDYMATE PRIVATE   57
# 4       STUDYMATE PRIVATE   57
# ...                   ...  ...
# ...

# %%
diabetes['AGE'].unique()
htn['AGE'].unique()
# Out:
# array([ 26,  57,  37,  31,  48,  59,  65,  58,  45,  55,  81,  67,  54,
#         74,  73,  53,  46,  49,  44,  52,  60,  64,  50,  56,  47,  61,
#         38,  43,  39,  69,  40,  51,  41,  76,  68,  14,  36,  42,  62,
#         66,  63,  35,  78,  34,  32,  84,  72,  23,  91,  71,  33,  28,
#         24,  29,  70,  18,  82,  80,  30,  77,  21,  75,  88,   9,  90,
#         83,  12,   3,  27,  89,  86,  85,  79,  87,  92,  94,  96,  25,
#         97,  13,  93,  10,  95,  98,  16,  19,  17,  11,  20,  15,   4,
#          2,  99,   7,  22,   1, 100,   6,   5,   8, 103])

# %%
# Diabetes # Selecting rows of Pandas Dataframe based on particular column value (Current Age) using ‘>=’ operator
diabetes = diabetes[diabetes['AGE'] >= 16] 
htn = htn[htn['AGE'] >= 16] 
diabetes
# Out:
#       BENEFICIARY  ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0       987884890          2      F     30         6800.00
# 1       987953280          7      M     90         2654.98
# 2       987953280          7      M    120        40914.28
# 3       987953280          7      M    120        55643.20
# 4       987953280          7      M     90         3573.25
# ...           ...        ...    ...    ...             ...
# 52611   942255892          7      F      8        44522.39
# 52612   942257694          6      M     60        33792.00
# 52613   942258297          5      M     30          513.59
# 52614   942258297          5      M     30         1071.89
# 52615   942267480          1      M     99         3500.00
#
#                  OPTION NAME  AGE
# 0          STUDYMATE PRIVATE   24
# 1                      ICARE   53
# 2                      ICARE   53
# 3                      ICARE   53
# 4                      ICARE   53
# ...                      ...  ...
# ...

# %%
htn
# Out:
#        BENEFICIARY  ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0        987855540          1      M   30.0         1063.22
# 1        987856780          6      F   30.0         1358.89
# 2        987856780          6      F   30.0         1819.49
# 3        987856780          6      F   30.0          306.07
# 4        987856780          6      F   30.0         1654.99
# ...            ...        ...    ...    ...             ...
# 218811   948668431          1      M   30.0         3500.00
# 218812   948668434          1      F   30.0         4763.96
# 218813   948989750          1      M   30.0         3899.19
# 218814   948982990         10      F   30.0            4.13
# 218815   948982991          1      M   60.0         4638.34
#
#               OPTION NAME  AGE
# 0       STUDYMATE PRIVATE   26
# 1       STUDYMATE PRIVATE   57
# 2       STUDYMATE PRIVATE   57
# 3       STUDYMATE PRIVATE   57
# 4       STUDYMATE PRIVATE   57
# ...                   ...  ...
# ...

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52388 entries, 0 to 52615
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   BENEFICIARY     52388 non-null  object
#  1   ADHERENCE       52388 non-null  int64
#  2   GENDER          52388 non-null  object
#  3   UNITS           52388 non-null  int64
#  4   AMOUNT CLAIMED  52388 non-null  float64
#  5   OPTION NAME     52388 non-null  object
#  6   AGE             52388 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.2+ MB

# %%
htn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 218660 entries, 0 to 218815
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   BENEFICIARY     218660 non-null  object
#  1   ADHERENCE       218660 non-null  int64
#  2   GENDER          218660 non-null  object
#  3   UNITS           218660 non-null  float64
#  4   AMOUNT CLAIMED  218660 non-null  float64
#  5   OPTION NAME     218660 non-null  object
#  6   AGE             218660 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 13.3+ MB

# %%
diabetes['ADHERENCE']=pd.cut(diabetes.ADHERENCE,bins=[1,8,12],labels=['NON-ADHERENT','ADHERENT']) 
htn['ADHERENCE']=pd.cut(htn.ADHERENCE,bins=[1,8,12],labels=['NON-ADHERENT','ADHERENT'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\1744258772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diabetes['ADHERENCE']=pd.cut(diabetes.ADHERENCE,bins=[1,8,12],labels=['NON-ADHERENT','ADHERENT'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\1744258772.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   htn['ADHERENCE']=pd.cut(htn.ADHERENCE,bins=[1,8,12],labels=['NON-ADHERENT','ADHERENT'])

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52388 entries, 0 to 52615
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   BENEFICIARY     52388 non-null  object
#  1   ADHERENCE       51550 non-null  category
#  2   GENDER          52388 non-null  object
#  3   UNITS           52388 non-null  int64
#  4   AMOUNT CLAIMED  52388 non-null  float64
#  5   OPTION NAME     52388 non-null  object
#  6   AGE             52388 non-null  int64
# dtypes: category(1), float64(1), int64(2), object(3)
# memory usage: 2.8+ MB

# %%
htn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 218660 entries, 0 to 218815
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   BENEFICIARY     218660 non-null  object
#  1   ADHERENCE       213797 non-null  category
#  2   GENDER          218660 non-null  object
#  3   UNITS           218660 non-null  float64
#  4   AMOUNT CLAIMED  218660 non-null  float64
#  5   OPTION NAME     218660 non-null  object
#  6   AGE             218660 non-null  int64
# dtypes: category(1), float64(2), int64(1), object(3)
# memory usage: 11.9+ MB

# %%
print(diabetes['ADHERENCE'].value_counts())
# Out:
# ADHERENCE
# ADHERENT        36195
# NON-ADHERENT    15355
# Name: count, dtype: int64

# %%
print(htn['ADHERENCE'].value_counts())
# Out:
# ADHERENCE
# ADHERENT        147037
# NON-ADHERENT     66760
# Name: count, dtype: int64

# %%
# Replace on NaN in the OMPLICATIONDEVELOPMENT column with NO_COMPLICATION'
diabetes['ADHERENCE'] = diabetes['ADHERENCE'].fillna('NON-ADHERENT')
htn['ADHERENCE'] = htn['ADHERENCE'].fillna('NON-ADHERENT')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\2890092221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diabetes['ADHERENCE'] = diabetes['ADHERENCE'].fillna('NON-ADHERENT')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\2890092221.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   htn['ADHERENCE'] = htn['ADHERENCE'].fillna('NON-ADHERENT')

# %%
Add_Columns= pd.read_csv(r'C:\Users\Lenovo\Downloads\Datasets- Diabetes and Hypertension Data\Datasets- Diabetes and Hypertension Data\Additional Columns\Additional Columns.csv')
Add_Columns
# Out:
#              OPTION NAME SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION
# 0      STUDYMATE PRIVATE      BASIC       STANDARD            690384.0
# 1               BASICARE      BASIC       STANDARD            808284.0
# 2                  ICARE     MEDIUM       STANDARD           2718696.0
# 3           PRIVATE LITE     MEDIUM       STANDARD           3864159.0
# 4       PRIVATE HOSPITAL    PREMIUM       STANDARD           6889900.0
# 5  PRIVATE HOSPITAL PLUS    PREMIUM  COMPREHENSIVE           6740121.0
# 6                MEDEXEC    PREMIUM  COMPREHENSIVE           8232361.5
# 7           MEDEXEC PLUS    PREMIUM  COMPREHENSIVE           9724602.0
# 8                  PRIME    PREMIUM  COMPREHENSIVE          11770788.0

# %%
# Matching Rows diabetes and Diabetes_Add_Column for annual contribution, schemetype and cover type # vLookup in Python using pandas 
   
diabetes = pd.merge(diabetes,  
                    Add_Columns,  
                     on ='OPTION NAME',  
                     how ='left') 
diabetes
# Out:
#       BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0       987884890  NON-ADHERENT      F     30         6800.00
# 1       987953280  NON-ADHERENT      M     90         2654.98
# 2       987953280  NON-ADHERENT      M    120        40914.28
# 3       987953280  NON-ADHERENT      M    120        55643.20
# 4       987953280  NON-ADHERENT      M     90         3573.25
# ...           ...           ...    ...    ...             ...
# 52383   942255892  NON-ADHERENT      F      8        44522.39
# 52384   942257694  NON-ADHERENT      M     60        33792.00
# 52385   942258297  NON-ADHERENT      M     30          513.59
# 52386   942258297  NON-ADHERENT      M     30         1071.89
# 52387   942267480  NON-ADHERENT      M     99         3500.00
#
#                  OPTION NAME  AGE SCHEMETYPE      COVERTYPE  \
# 0          STUDYMATE PRIVATE   24      BASIC       STANDARD
# 1                      ICARE   53     MEDIUM       STANDARD
# ...

# %%
Htn_Add_Columns= pd.read_csv(r'C:\Users\Lenovo\Downloads\Datasets- Diabetes and Hypertension Data\Datasets- Diabetes and Hypertension Data\Additional Columns\HTN_Additional Columns.csv')
Htn_Add_Columns
# Out:
#              OPTION NAME SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION
# 0       STUDYMATE PUBLIC      BASIC       STANDARD            211764.0
# 1      STUDYMATE PRIVATE      BASIC       STANDARD            690384.0
# 2               BASICARE      BASIC       STANDARD            808284.0
# 3                  ICARE     MEDIUM       STANDARD           2718696.0
# 4           PRIVATE LITE     MEDIUM       STANDARD           3864159.0
# 5       PRIVATE HOSPITAL    PREMIUM       STANDARD           6889900.0
# 6  PRIVATE HOSPITAL PLUS    PREMIUM  COMPREHENSIVE           6740121.0
# 7                MEDEXEC    PREMIUM  COMPREHENSIVE           8232361.5
# 8           MEDEXEC PLUS    PREMIUM  COMPREHENSIVE           9724602.0
# 9                  PRIME    PREMIUM  COMPREHENSIVE          11770788.0

# %%
# Matching Rows diabetes and Diabetes_Add_Column for annual contribution, schemetype and cover type # vLookup in Python using pandas 
   
htn = pd.merge(htn,  
                    Htn_Add_Columns,  
                     on ='OPTION NAME',  
                     how ='left') 
htn
# Out:
#        BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0        987855540  NON-ADHERENT      M   30.0         1063.22
# 1        987856780  NON-ADHERENT      F   30.0         1358.89
# 2        987856780  NON-ADHERENT      F   30.0         1819.49
# 3        987856780  NON-ADHERENT      F   30.0          306.07
# 4        987856780  NON-ADHERENT      F   30.0         1654.99
# ...            ...           ...    ...    ...             ...
# 218655   948668431  NON-ADHERENT      M   30.0         3500.00
# 218656   948668434  NON-ADHERENT      F   30.0         4763.96
# 218657   948989750  NON-ADHERENT      M   30.0         3899.19
# 218658   948982990      ADHERENT      F   30.0            4.13
# 218659   948982991  NON-ADHERENT      M   60.0         4638.34
#
#               OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION
# 0       STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
neurology = pd.read_csv(r'C:\Users\Lenovo\Downloads\Datasets- Diabetes and Hypertension Data\Datasets- Diabetes and Hypertension Data\Complications Development\Neurology.csv')
opthamol = pd.read_csv(r'C:\Users\Lenovo\Downloads\Datasets- Diabetes and Hypertension Data\Datasets- Diabetes and Hypertension Data\Complications Development\Opthamol.csv')
physician = pd.read_csv(r'C:\Users\Lenovo\Downloads\Datasets- Diabetes and Hypertension Data\Datasets- Diabetes and Hypertension Data\Complications Development\Physician.csv')
dialysis = pd.read_csv(r'C:\Users\Lenovo\Downloads\Datasets- Diabetes and Hypertension Data\Datasets- Diabetes and Hypertension Data\Complications Development\Dialysis.csv')

# %%
neurology
# Out:
#     BENEFICIARY  NEUROLOGY
# 0     979297520  Neurology
# 1     979297520  Neurology
# 2     979876490  Neurology
# 3     979876490  Neurology
# 4     979892460  Neurology
# ..          ...        ...
# 93    929359951  Neurology
# 94    929359951  Neurology
# 95    942257320  Neurology
# 96    942257320  Neurology
# 97    942257323  Neurology
#
# [98 rows x 2 columns]

# %%
opthamol
# Out:
#        BENEFICIARY      OPTHAMOL
# 0        978946571  Opthamolgist
# 1        978946571  Opthamolgist
# 2        978946571  Opthamolgist
# 3        978273920  Opthamolgist
# 4        978273920  Opthamolgist
# ...            ...           ...
# 20341    946778780  Opthamolgist
# 20342    946778780  Opthamolgist
# 20343    946778780  Opthamolgist
# 20344    946234460  Opthamolgist
# 20345    946234460  Opthamolgist
#
# [20346 rows x 2 columns]

# %%
physician
# Out:
#        BENEFICIARY  PHYSICIAN
# 0        977856430  Physician
# 1        977879360  Physician
# 2        977897830  Physician
# 3        978946571  Physician
# 4        978946571  Physician
# ...            ...        ...
# 24262    946259930  Physician
# 24263    946259930  Physician
# 24264    946259930  Physician
# 24265    946477931  Physician
# 24266    948547731  Physician
#
# [24267 rows x 2 columns]

# %%
dialysis
# Out:
#       BENEFICIARY  DIALYSIS
# 0       979489750  Dialysis
# 1       979489750  Dialysis
# 2       979489750  Dialysis
# 3       979489750  Dialysis
# 4       979489750  Dialysis
# ...           ...       ...
# 9774    943269360  Dialysis
# 9775    943269360  Dialysis
# 9776    943269360  Dialysis
# 9777    943269360  Dialysis
# 9778    943269360  Dialysis
#
# [9779 rows x 2 columns]

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52388 entries, 0 to 52387
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BENEFICIARY         52388 non-null  object
#  1   ADHERENCE           52388 non-null  category
#  2   GENDER              52388 non-null  object
#  3   UNITS               52388 non-null  int64
#  4   AMOUNT CLAIMED      52388 non-null  float64
#  5   OPTION NAME         52388 non-null  object
#  6   AGE                 52388 non-null  int64
#  7   SCHEMETYPE          52388 non-null  object
#  8   COVERTYPE           52388 non-null  object
#  9   ANNUALCONTRIBUTION  52388 non-null  float64
# dtypes: category(1), float64(2), int64(2), object(5)
# memory usage: 3.6+ MB

# %%
htn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218660 entries, 0 to 218659
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   BENEFICIARY         218660 non-null  object
#  1   ADHERENCE           218660 non-null  category
#  2   GENDER              218660 non-null  object
#  3   UNITS               218660 non-null  float64
#  4   AMOUNT CLAIMED      218660 non-null  float64
#  5   OPTION NAME         218660 non-null  object
#  6   AGE                 218660 non-null  int64
#  7   SCHEMETYPE          218660 non-null  object
#  8   COVERTYPE           218660 non-null  object
#  9   ANNUALCONTRIBUTION  218660 non-null  float64
# dtypes: category(1), float64(3), int64(1), object(5)
# memory usage: 15.2+ MB

# %%
diabetes['BENEFICIARY'] = diabetes['BENEFICIARY'].astype('int64')
htn['BENEFICIARY'] = htn['BENEFICIARY'].astype('int64')

# %%
# Matching Rows diabetes and neurology for the Complication Development Neorology # vLookup in Python using pandas 
   
diabetes = pd.merge(diabetes,  
                    neurology,
                    on ='BENEFICIARY',  
                    how ='left')

# %%
# Matching Rows diabetes and neurology for the Complication Development opthamol # vLookup in Python using pandas 
   
diabetes = pd.merge(diabetes,  
                     opthamol,
                     on ='BENEFICIARY',  
                     how ='left')

# %%
# Matching Rows diabetes and neurology for the Complication Development physician # vLookup in Python using pandas 
   
diabetes = pd.merge(diabetes,  
                    physician,
                     on ='BENEFICIARY',  
                     how ='left')

# %%
# Matching Rows diabetes and neurology for the Complication Development dialysis # vLookup in Python using pandas 
   
diabetes = pd.merge(diabetes,  
                    dialysis,
                     on ='BENEFICIARY',  
                     how ='left')

# %%
diabetes
# Out:
#         BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0         987884890  NON-ADHERENT      F     30         6800.00
# 1         987953280  NON-ADHERENT      M     90         2654.98
# 2         987953280  NON-ADHERENT      M    120        40914.28
# 3         987953280  NON-ADHERENT      M    120        55643.20
# 4         987953280  NON-ADHERENT      M     90         3573.25
# ...             ...           ...    ...    ...             ...
# 516405    942255892  NON-ADHERENT      F      8        44522.39
# 516406    942257694  NON-ADHERENT      M     60        33792.00
# 516407    942258297  NON-ADHERENT      M     30          513.59
# 516408    942258297  NON-ADHERENT      M     30         1071.89
# 516409    942267480  NON-ADHERENT      M     99         3500.00
#
#                   OPTION NAME  AGE SCHEMETYPE      COVERTYPE  \
# 0           STUDYMATE PRIVATE   24      BASIC       STANDARD
# 1                       ICARE   53     MEDIUM       STANDARD
# ...

# %%
# Matching Rows htn and neurology for the Complication Development Neorology # vLookup in Python using pandas 
   
htn = pd.merge(htn,  
                     neurology,
                     on ='BENEFICIARY',  
                     how ='left')

# %%
# Matching Rows diabetes and opthamol for the Complication Development opthamol # vLookup in Python using pandas 
   
htn= pd.merge(htn,  
                     opthamol,
                     on ='BENEFICIARY',  
                     how ='left')

# %%
# Matching Rows diabetes and neurology for the Complication Development physician # vLookup in Python using pandas 
   
htn = pd.merge(htn,  
                    physician,
                     on ='BENEFICIARY',  
                     how ='left')

# %%
# Matching Rows diabetes and neurology for the Complication Development dialysis # vLookup in Python using pandas 
   
htn = pd.merge(htn,  
                    dialysis,
                     on ='BENEFICIARY',  
                     how ='left')

# %%
htn
# Out:
#          BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0          987855540  NON-ADHERENT      M   30.0         1063.22
# 1          987856780  NON-ADHERENT      F   30.0         1358.89
# 2          987856780  NON-ADHERENT      F   30.0         1819.49
# 3          987856780  NON-ADHERENT      F   30.0          306.07
# 4          987856780  NON-ADHERENT      F   30.0         1654.99
# ...              ...           ...    ...    ...             ...
# 1060091    948668431  NON-ADHERENT      M   30.0         3500.00
# 1060092    948668434  NON-ADHERENT      F   30.0         4763.96
# 1060093    948989750  NON-ADHERENT      M   30.0         3899.19
# 1060094    948982990      ADHERENT      F   30.0            4.13
# 1060095    948982991  NON-ADHERENT      M   60.0         4638.34
#
#                OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0        STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
diabetes.NEUROLOGY = diabetes.NEUROLOGY.fillna('NO')
diabetes.OPTHAMOL = diabetes.OPTHAMOL.fillna('NO')
diabetes.PHYSICIAN = diabetes.PHYSICIAN.fillna('NO')
diabetes.DIALYSIS = diabetes.DIALYSIS.fillna('NO')

diabetes['NEUROLOGY'] = diabetes['NEUROLOGY'].replace('Neurology','YES')
diabetes['OPTHAMOL'] = diabetes['OPTHAMOL'].replace('Opthamolgist','YES')
diabetes['PHYSICIAN'] = diabetes['PHYSICIAN'].replace('Physician','YES')
diabetes['DIALYSIS'] = diabetes['DIALYSIS'].replace('Dialysis','YES')

diabetes
# Out:
#         BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0         987884890  NON-ADHERENT      F     30         6800.00
# 1         987953280  NON-ADHERENT      M     90         2654.98
# 2         987953280  NON-ADHERENT      M    120        40914.28
# 3         987953280  NON-ADHERENT      M    120        55643.20
# 4         987953280  NON-ADHERENT      M     90         3573.25
# ...             ...           ...    ...    ...             ...
# 516405    942255892  NON-ADHERENT      F      8        44522.39
# 516406    942257694  NON-ADHERENT      M     60        33792.00
# 516407    942258297  NON-ADHERENT      M     30          513.59
# 516408    942258297  NON-ADHERENT      M     30         1071.89
# 516409    942267480  NON-ADHERENT      M     99         3500.00
#
#                   OPTION NAME  AGE SCHEMETYPE      COVERTYPE  \
# 0           STUDYMATE PRIVATE   24      BASIC       STANDARD
# 1                       ICARE   53     MEDIUM       STANDARD
# ...

# %%
htn.NEUROLOGY = htn.NEUROLOGY.fillna('NO')
htn.OPTHAMOL = htn.OPTHAMOL.fillna('NO')
htn.PHYSICIAN = htn.PHYSICIAN.fillna('NO')
htn.DIALYSIS = htn.DIALYSIS.fillna('NO')

htn['NEUROLOGY'] = htn['NEUROLOGY'].replace('Neurology','YES')
htn['OPTHAMOL'] = htn['OPTHAMOL'].replace('Opthamolgist','YES')
htn['PHYSICIAN'] = htn['PHYSICIAN'].replace('Physician','YES')
htn['DIALYSIS'] = htn['DIALYSIS'].replace('Dialysis','YES')

htn
# Out:
#          BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0          987855540  NON-ADHERENT      M   30.0         1063.22
# 1          987856780  NON-ADHERENT      F   30.0         1358.89
# 2          987856780  NON-ADHERENT      F   30.0         1819.49
# 3          987856780  NON-ADHERENT      F   30.0          306.07
# 4          987856780  NON-ADHERENT      F   30.0         1654.99
# ...              ...           ...    ...    ...             ...
# 1060091    948668431  NON-ADHERENT      M   30.0         3500.00
# 1060092    948668434  NON-ADHERENT      F   30.0         4763.96
# 1060093    948989750  NON-ADHERENT      M   30.0         3899.19
# 1060094    948982990      ADHERENT      F   30.0            4.13
# 1060095    948982991  NON-ADHERENT      M   60.0         4638.34
#
#                OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0        STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
diabetes['NEUROLOGY'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
diabetes["NEUROLOGY"].value_counts()
# Out:
# NEUROLOGY
# NO     516114
# YES       296
# Name: count, dtype: int64

# %%
diabetes['OPTHAMOL'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
diabetes["OPTHAMOL"].value_counts()
# Out:
# OPTHAMOL
# YES    430007
# NO      86403
# Name: count, dtype: int64

# %%
diabetes['PHYSICIAN'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
diabetes["PHYSICIAN"].value_counts()
# Out:
# PHYSICIAN
# YES    458390
# NO      58020
# Name: count, dtype: int64

# %%
diabetes['DIALYSIS'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
diabetes["DIALYSIS"].value_counts()
# Out:
# DIALYSIS
# YES    420041
# NO      96369
# Name: count, dtype: int64

# %%
htn['NEUROLOGY'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
htn["NEUROLOGY"].value_counts()
# Out:
# NEUROLOGY
# NO     1058766
# YES       1330
# Name: count, dtype: int64

# %%
htn['OPTHAMOL'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
htn["OPTHAMOL"].value_counts()
# Out:
# OPTHAMOL
# YES    679532
# NO     380564
# Name: count, dtype: int64

# %%
htn['PHYSICIAN'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
htn["PHYSICIAN"].value_counts()
# Out:
# PHYSICIAN
# YES    803078
# NO     257018
# Name: count, dtype: int64

# %%
htn['DIALYSIS'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
htn["DIALYSIS"].value_counts()
# Out:
# DIALYSIS
# YES    696976
# NO     363120
# Name: count, dtype: int64

# %%
diabetes.loc[(diabetes['NEUROLOGY'] == 'YES') | (diabetes['OPTHAMOL'] == 'YES') |
                      (diabetes['PHYSICIAN'] == 'YES') |   (diabetes['DIALYSIS'] == 'YES'),'COMPLICATIONDEVELOPMENT'] = 'COMPLICATION' 
diabetes.loc[(diabetes['NEUROLOGY'] != 'NO') & (diabetes['OPTHAMOL'] != 'NO') & (diabetes['PHYSICIAN'] != 'NO') &
                      (diabetes['DIALYSIS'] != 'NO'), 'COMPLICATIONDEVELOPMENT'] = 'NO_COMPLICATION'

# %%
diabetes['COMPLICATIONDEVELOPMENT'].unique()
# Out:
# array([nan, 'COMPLICATION'], dtype=object)

# %%
diabetes
# Out:
#         BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0         987884890  NON-ADHERENT      F     30         6800.00
# 1         987953280  NON-ADHERENT      M     90         2654.98
# 2         987953280  NON-ADHERENT      M    120        40914.28
# 3         987953280  NON-ADHERENT      M    120        55643.20
# 4         987953280  NON-ADHERENT      M     90         3573.25
# ...             ...           ...    ...    ...             ...
# 516405    942255892  NON-ADHERENT      F      8        44522.39
# 516406    942257694  NON-ADHERENT      M     60        33792.00
# 516407    942258297  NON-ADHERENT      M     30          513.59
# 516408    942258297  NON-ADHERENT      M     30         1071.89
# 516409    942267480  NON-ADHERENT      M     99         3500.00
#
#                   OPTION NAME  AGE SCHEMETYPE      COVERTYPE  \
# 0           STUDYMATE PRIVATE   24      BASIC       STANDARD
# 1                       ICARE   53     MEDIUM       STANDARD
# ...

# %%
# Replace on NaN in the OMPLICATIONDEVELOPMENT column with NO_COMPLICATION'
diabetes["COMPLICATIONDEVELOPMENT"] = diabetes["COMPLICATIONDEVELOPMENT"].fillna('NO_COMPLICATION')

# %%
diabetes['COMPLICATIONDEVELOPMENT'].isnull().values.any()
# Out:
# np.False_

# %%
diabetes['COMPLICATIONDEVELOPMENT'].isnull().sum()
# Out:
# np.int64(0)

# %%
diabetes['COMPLICATIONDEVELOPMENT'].unique()
# Out:
# array(['NO_COMPLICATION', 'COMPLICATION'], dtype=object)

# %%
diabetes['COMPLICATIONDEVELOPMENT'].value_counts()
# Out:
# COMPLICATIONDEVELOPMENT
# COMPLICATION       471045
# NO_COMPLICATION     45365
# Name: count, dtype: int64

# %%
htn.loc[(htn['NEUROLOGY'] == 'YES') | (htn['OPTHAMOL'] == 'YES') |
                      (htn['PHYSICIAN'] == 'YES') |   (htn['DIALYSIS'] == 'YES'),'COMPLICATIONDEVELOPMENT'] = 'COMPLICATION' 
htn.loc[(htn['NEUROLOGY'] != 'NO') & (htn['OPTHAMOL'] != 'NO') & (htn['PHYSICIAN'] != 'NO') &
                      (htn['DIALYSIS'] != 'NO'), 'COMPLICATIONDEVELOPMENT'] = 'NO_COMPLICATION'

# %%
diabetes['COMPLICATIONDEVELOPMENT'].unique()
# Out:
# array(['NO_COMPLICATION', 'COMPLICATION'], dtype=object)

# %%
htn
# Out:
#          BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0          987855540  NON-ADHERENT      M   30.0         1063.22
# 1          987856780  NON-ADHERENT      F   30.0         1358.89
# 2          987856780  NON-ADHERENT      F   30.0         1819.49
# 3          987856780  NON-ADHERENT      F   30.0          306.07
# 4          987856780  NON-ADHERENT      F   30.0         1654.99
# ...              ...           ...    ...    ...             ...
# 1060091    948668431  NON-ADHERENT      M   30.0         3500.00
# 1060092    948668434  NON-ADHERENT      F   30.0         4763.96
# 1060093    948989750  NON-ADHERENT      M   30.0         3899.19
# 1060094    948982990      ADHERENT      F   30.0            4.13
# 1060095    948982991  NON-ADHERENT      M   60.0         4638.34
#
#                OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0        STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
# Replace on NaN in the OMPLICATIONDEVELOPMENT column with NO_COMPLICATION'
htn["COMPLICATIONDEVELOPMENT"] = htn["COMPLICATIONDEVELOPMENT"].fillna('NO_COMPLICATION')

# %%
htn['COMPLICATIONDEVELOPMENT'].unique()
# Out:
# array(['NO_COMPLICATION', 'COMPLICATION'], dtype=object)

# %%
htn['COMPLICATIONDEVELOPMENT'].value_counts()
# Out:
# COMPLICATIONDEVELOPMENT
# COMPLICATION       863850
# NO_COMPLICATION    196246
# Name: count, dtype: int64

# %%
htn['COMPLICATIONDEVELOPMENT'].isnull().values.any()
# Out:
# np.False_

# %%
htn['COMPLICATIONDEVELOPMENT'].isnull().sum()
# Out:
# np.int64(0)

# %%
diabetes.columns
# Out:
# Index(['BENEFICIARY', 'ADHERENCE', 'GENDER', 'UNITS', 'AMOUNT CLAIMED',
#        'OPTION NAME', 'AGE', 'SCHEMETYPE', 'COVERTYPE', 'ANNUALCONTRIBUTION',
#        'NEUROLOGY', 'OPTHAMOL', 'PHYSICIAN', 'DIALYSIS',
#        'COMPLICATIONDEVELOPMENT'],
#       dtype='object')

# %%
diabetes_unique = diabetes.groupby('BENEFICIARY')[['AMOUNT CLAIMED']].sum()
diabetes_unique
# Out:
#              AMOUNT CLAIMED
# BENEFICIARY
# 922228881           7471.51
# 922229691         220063.61
# 922238951         149966.44
# 922246750         328113.24
# 922259850          73750.24
# ...                     ...
# 9299835914         60270.09
# 9897482210         87190.16
# 9898723911         26400.01
# 9899388811        319501.08
# 9988444910        178583.34
#
# [4805 rows x 1 columns]

# %%
diabetes_unique.rename(columns={"AMOUNT CLAIMED": "ANNUALCLAIMAMOUNT"}, inplace=True)
diabetes_unique
# Out:
#              ANNUALCLAIMAMOUNT
# BENEFICIARY
# 922228881              7471.51
# 922229691            220063.61
# 922238951            149966.44
# 922246750            328113.24
# 922259850             73750.24
# ...                        ...
# 9299835914            60270.09
# 9897482210            87190.16
# 9898723911            26400.01
# 9899388811           319501.08
# 9988444910           178583.34
#
# [4805 rows x 1 columns]

# %%
# Matching Rows dfdiabtes and dfdiabtes_unique for the ANNUALCLAIMAMOUNT # vLookup in Python using pandas 
   
diabetes = pd.merge(diabetes,  
                     diabetes_unique,  
                     on ='BENEFICIARY',  
                     how ='left') 
diabetes
# Out:
#         BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0         987884890  NON-ADHERENT      F     30         6800.00
# 1         987953280  NON-ADHERENT      M     90         2654.98
# 2         987953280  NON-ADHERENT      M    120        40914.28
# 3         987953280  NON-ADHERENT      M    120        55643.20
# 4         987953280  NON-ADHERENT      M     90         3573.25
# ...             ...           ...    ...    ...             ...
# 516405    942255892  NON-ADHERENT      F      8        44522.39
# 516406    942257694  NON-ADHERENT      M     60        33792.00
# 516407    942258297  NON-ADHERENT      M     30          513.59
# 516408    942258297  NON-ADHERENT      M     30         1071.89
# 516409    942267480  NON-ADHERENT      M     99         3500.00
#
#                   OPTION NAME  AGE SCHEMETYPE      COVERTYPE  \
# 0           STUDYMATE PRIVATE   24      BASIC       STANDARD
# 1                       ICARE   53     MEDIUM       STANDARD
# ...

# %%
htn.columns
# Out:
# Index(['BENEFICIARY', 'ADHERENCE', 'GENDER', 'UNITS', 'AMOUNT CLAIMED',
#        'OPTION NAME', 'AGE', 'SCHEMETYPE', 'COVERTYPE', 'ANNUALCONTRIBUTION',
#        'NEUROLOGY', 'OPTHAMOL', 'PHYSICIAN', 'DIALYSIS',
#        'COMPLICATIONDEVELOPMENT'],
#       dtype='object')

# %%
htn_unique = htn.groupby('BENEFICIARY')[['AMOUNT CLAIMED']].sum()
htn_unique
# Out:
#              AMOUNT CLAIMED
# BENEFICIARY
# 922223651          21435.44
# 922224360        3316130.50
# 922224450          18062.42
# 922224890          67146.13
# 922224891           2820.05
# ...                     ...
# 9986786910          3444.23
# 9988444910         22512.23
# 9989539510        149697.16
# 9998473412         17173.25
# 9998955910          4325.89
#
# [19279 rows x 1 columns]

# %%
htn_unique.rename(columns={"AMOUNT CLAIMED": "ANNUALCLAIMAMOUNT"}, inplace=True)
htn_unique
# Out:
#              ANNUALCLAIMAMOUNT
# BENEFICIARY
# 922223651             21435.44
# 922224360           3316130.50
# 922224450             18062.42
# 922224890             67146.13
# 922224891              2820.05
# ...                        ...
# 9986786910             3444.23
# 9988444910            22512.23
# 9989539510           149697.16
# 9998473412            17173.25
# 9998955910             4325.89
#
# [19279 rows x 1 columns]

# %%
# Matching Rows htn and htn_unique for the ANNUALCLAIMAMOUNT # vLookup in Python using pandas 
   
htn = pd.merge(htn,  
                    htn_unique,  
                     on ='BENEFICIARY',  
                     how ='left') 
htn
# Out:
#          BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0          987855540  NON-ADHERENT      M   30.0         1063.22
# 1          987856780  NON-ADHERENT      F   30.0         1358.89
# 2          987856780  NON-ADHERENT      F   30.0         1819.49
# 3          987856780  NON-ADHERENT      F   30.0          306.07
# 4          987856780  NON-ADHERENT      F   30.0         1654.99
# ...              ...           ...    ...    ...             ...
# 1060091    948668431  NON-ADHERENT      M   30.0         3500.00
# 1060092    948668434  NON-ADHERENT      F   30.0         4763.96
# 1060093    948989750  NON-ADHERENT      M   30.0         3899.19
# 1060094    948982990      ADHERENT      F   30.0            4.13
# 1060095    948982991  NON-ADHERENT      M   60.0         4638.34
#
#                OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0        STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
htn_unitstotal = htn.groupby('BENEFICIARY')[['UNITS']].sum()
htn_unitstotal.rename(columns={"UNITS": "UNITSTOTAL"}, inplace=True)
htn_unitstotal
# Out:
#              UNITSTOTAL
# BENEFICIARY
# 922223651          28.0
# 922224360       28500.0
# 922224450         100.0
# 922224890         318.0
# 922224891          28.0
# ...                 ...
# 9986786910         60.0
# 9988444910        390.0
# 9989539510        218.0
# 9998473412        150.0
# 9998955910         90.0
#
# [19279 rows x 1 columns]

# %%
# Matching Rows htn and htn_unitstotal for the ANNUALUNITS # vLookup in Python using pandas 
   
htn = pd.merge(htn,  
                     htn_unitstotal,  
                     on ='BENEFICIARY',  
                     how ='left') 
htn
# Out:
#          BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0          987855540  NON-ADHERENT      M   30.0         1063.22
# 1          987856780  NON-ADHERENT      F   30.0         1358.89
# 2          987856780  NON-ADHERENT      F   30.0         1819.49
# 3          987856780  NON-ADHERENT      F   30.0          306.07
# 4          987856780  NON-ADHERENT      F   30.0         1654.99
# ...              ...           ...    ...    ...             ...
# 1060091    948668431  NON-ADHERENT      M   30.0         3500.00
# 1060092    948668434  NON-ADHERENT      F   30.0         4763.96
# 1060093    948989750  NON-ADHERENT      M   30.0         3899.19
# 1060094    948982990      ADHERENT      F   30.0            4.13
# 1060095    948982991  NON-ADHERENT      M   60.0         4638.34
#
#                OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0        STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
diabetes_unitstotal = diabetes.groupby('BENEFICIARY')[['UNITS']].sum()
diabetes_unitstotal.rename(columns={"UNITS": "UNITSTOTAL"}, inplace=True)
diabetes_unitstotal
# Out:
#              UNITSTOTAL
# BENEFICIARY
# 922228881           300
# 922229691          1200
# 922238951           381
# 922246750            54
# 922259850           480
# ...                 ...
# 9299835914          330
# 9897482210           26
# 9898723911          120
# 9899388811         1350
# 9988444910          780
#
# [4805 rows x 1 columns]

# %%
# Matching Rows dfdiabetes and dfdiabetes_unitstotal for the Annual UNITSTOTAL # vLookup in Python using pandas 
   
diabetes = pd.merge(diabetes,  
                     diabetes_unitstotal,  
                     on ='BENEFICIARY',  
                     how ='left') 
diabetes
# Out:
#         BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0         987884890  NON-ADHERENT      F     30         6800.00
# 1         987953280  NON-ADHERENT      M     90         2654.98
# 2         987953280  NON-ADHERENT      M    120        40914.28
# 3         987953280  NON-ADHERENT      M    120        55643.20
# 4         987953280  NON-ADHERENT      M     90         3573.25
# ...             ...           ...    ...    ...             ...
# 516405    942255892  NON-ADHERENT      F      8        44522.39
# 516406    942257694  NON-ADHERENT      M     60        33792.00
# 516407    942258297  NON-ADHERENT      M     30          513.59
# 516408    942258297  NON-ADHERENT      M     30         1071.89
# 516409    942267480  NON-ADHERENT      M     99         3500.00
#
#                   OPTION NAME  AGE SCHEMETYPE      COVERTYPE  \
# 0           STUDYMATE PRIVATE   24      BASIC       STANDARD
# 1                       ICARE   53     MEDIUM       STANDARD
# ...

# %%
diabetes.drop_duplicates(subset=['BENEFICIARY'], inplace=True)
htn.drop_duplicates(subset=['BENEFICIARY'], inplace=True)
diabetes
# Out:
#         BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0         987884890  NON-ADHERENT      F     30         6800.00
# 1         987953280  NON-ADHERENT      M     90         2654.98
# 12        987996650  NON-ADHERENT      M     60        17640.00
# 18        988899920  NON-ADHERENT      M     60        10654.25
# 26        988828890      ADHERENT      F     60        10654.25
# ...             ...           ...    ...    ...             ...
# 516252    939458560  NON-ADHERENT      M     60         1819.49
# 516269    939828690  NON-ADHERENT      M     15         1050.00
# 516347    948928640  NON-ADHERENT      M     60         4134.43
# 516356    949872540  NON-ADHERENT      M     30          640.00
# 516409    942267480  NON-ADHERENT      M     99         3500.00
#
#               OPTION NAME  AGE SCHEMETYPE COVERTYPE  ANNUALCONTRIBUTION  \
# 0       STUDYMATE PRIVATE   24      BASIC  STANDARD            690384.0
# ...

# %%
htn
# Out:
#          BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0          987855540  NON-ADHERENT      M   30.0         1063.22
# 1          987856780  NON-ADHERENT      F   30.0         1358.89
# 16         987862940  NON-ADHERENT      F   60.0         1029.88
# 18         987864650  NON-ADHERENT      M    1.0          128.75
# 20         987999990  NON-ADHERENT      M   60.0         2375.85
# ...              ...           ...    ...    ...             ...
# 1060091    948668431  NON-ADHERENT      M   30.0         3500.00
# 1060092    948668434  NON-ADHERENT      F   30.0         4763.96
# 1060093    948989750  NON-ADHERENT      M   30.0         3899.19
# 1060094    948982990      ADHERENT      F   30.0            4.13
# 1060095    948982991  NON-ADHERENT      M   60.0         4638.34
#
#                OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0        STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
# Creating the Diagonosis Column with the entire column populated with the 'DIABETES' diagnosis value
diabetes['DIAGNOSIS'] = 'DIABETES'

# %%
diabetes
# Out:
#         BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0         987884890  NON-ADHERENT      F     30         6800.00
# 1         987953280  NON-ADHERENT      M     90         2654.98
# 12        987996650  NON-ADHERENT      M     60        17640.00
# 18        988899920  NON-ADHERENT      M     60        10654.25
# 26        988828890      ADHERENT      F     60        10654.25
# ...             ...           ...    ...    ...             ...
# 516252    939458560  NON-ADHERENT      M     60         1819.49
# 516269    939828690  NON-ADHERENT      M     15         1050.00
# 516347    948928640  NON-ADHERENT      M     60         4134.43
# 516356    949872540  NON-ADHERENT      M     30          640.00
# 516409    942267480  NON-ADHERENT      M     99         3500.00
#
#               OPTION NAME  AGE SCHEMETYPE COVERTYPE  ANNUALCONTRIBUTION  \
# 0       STUDYMATE PRIVATE   24      BASIC  STANDARD            690384.0
# ...

# %%
# Creating the Diagonosis Column with the entire column populated with the 'HYPERTENSION' diagnosis value
htn['DIAGNOSIS'] = 'HYPERTENSION'
htn
# Out:
#          BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0          987855540  NON-ADHERENT      M   30.0         1063.22
# 1          987856780  NON-ADHERENT      F   30.0         1358.89
# 16         987862940  NON-ADHERENT      F   60.0         1029.88
# 18         987864650  NON-ADHERENT      M    1.0          128.75
# 20         987999990  NON-ADHERENT      M   60.0         2375.85
# ...              ...           ...    ...    ...             ...
# 1060091    948668431  NON-ADHERENT      M   30.0         3500.00
# 1060092    948668434  NON-ADHERENT      F   30.0         4763.96
# 1060093    948989750  NON-ADHERENT      M   30.0         3899.19
# 1060094    948982990      ADHERENT      F   30.0            4.13
# 1060095    948982991  NON-ADHERENT      M   60.0         4638.34
#
#                OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0        STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
# Using DataFrame.copy() to create new sub-DaraFrame from the diabetes and htn with beneficiary and diagnosis
diabetes_copy = diabetes[['BENEFICIARY', 'DIAGNOSIS']].copy()
htn_copy = htn[['BENEFICIARY', 'DIAGNOSIS']].copy()
diabetes_copy
# Out:
#         BENEFICIARY DIAGNOSIS
# 0         987884890  DIABETES
# 1         987953280  DIABETES
# 12        987996650  DIABETES
# 18        988899920  DIABETES
# 26        988828890  DIABETES
# ...             ...       ...
# 516252    939458560  DIABETES
# 516269    939828690  DIABETES
# 516347    948928640  DIABETES
# 516356    949872540  DIABETES
# 516409    942267480  DIABETES
#
# [4805 rows x 2 columns]

# %%
htn_copy
# Out:
#          BENEFICIARY     DIAGNOSIS
# 0          987855540  HYPERTENSION
# 1          987856780  HYPERTENSION
# 16         987862940  HYPERTENSION
# 18         987864650  HYPERTENSION
# 20         987999990  HYPERTENSION
# ...              ...           ...
# 1060091    948668431  HYPERTENSION
# 1060092    948668434  HYPERTENSION
# 1060093    948989750  HYPERTENSION
# 1060094    948982990  HYPERTENSION
# 1060095    948982991  HYPERTENSION
#
# [19279 rows x 2 columns]

# %%
# Rename the DIAGNOSIS columns in the diabetes_copy and htn_copy to COMORBIDITY
diabetes_copy.rename(columns={"DIAGNOSIS": "COMORBIDITY"}, inplace=True)
htn_copy.rename(columns={"DIAGNOSIS": "COMORBIDITY"}, inplace=True)
diabetes_copy
# Out:
#         BENEFICIARY COMORBIDITY
# 0         987884890    DIABETES
# 1         987953280    DIABETES
# 12        987996650    DIABETES
# 18        988899920    DIABETES
# 26        988828890    DIABETES
# ...             ...         ...
# 516252    939458560    DIABETES
# 516269    939828690    DIABETES
# 516347    948928640    DIABETES
# 516356    949872540    DIABETES
# 516409    942267480    DIABETES
#
# [4805 rows x 2 columns]

# %%
htn_copy
# Out:
#          BENEFICIARY   COMORBIDITY
# 0          987855540  HYPERTENSION
# 1          987856780  HYPERTENSION
# 16         987862940  HYPERTENSION
# 18         987864650  HYPERTENSION
# 20         987999990  HYPERTENSION
# ...              ...           ...
# 1060091    948668431  HYPERTENSION
# 1060092    948668434  HYPERTENSION
# 1060093    948989750  HYPERTENSION
# 1060094    948982990  HYPERTENSION
# 1060095    948982991  HYPERTENSION
#
# [19279 rows x 2 columns]

# %%
# Matching Rows benefeciary in the htn for the Cormobidity variableL # vLookup in Python using pandas 
   
htn = pd.merge(htn,  
               diabetes_copy,  
                on ='BENEFICIARY',  
                how ='left') 
htn
# Out:
#        BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0        987855540  NON-ADHERENT      M   30.0         1063.22
# 1        987856780  NON-ADHERENT      F   30.0         1358.89
# 2        987862940  NON-ADHERENT      F   60.0         1029.88
# 3        987864650  NON-ADHERENT      M    1.0          128.75
# 4        987999990  NON-ADHERENT      M   60.0         2375.85
# ...            ...           ...    ...    ...             ...
# 19274    948668431  NON-ADHERENT      M   30.0         3500.00
# 19275    948668434  NON-ADHERENT      F   30.0         4763.96
# 19276    948989750  NON-ADHERENT      M   30.0         3899.19
# 19277    948982990      ADHERENT      F   30.0            4.13
# 19278    948982991  NON-ADHERENT      M   60.0         4638.34
#
#              OPTION NAME  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0      STUDYMATE PRIVATE   26      BASIC       STANDARD            690384.0
# ...

# %%
# Matching Rows benefeciary in the diabetes for the Cormobidity variableL # vLookup in Python using pandas 
   
diabetes = pd.merge(diabetes,  
               htn_copy,  
                on ='BENEFICIARY',  
                how ='left') 
diabetes
# Out:
#       BENEFICIARY     ADHERENCE GENDER  UNITS  AMOUNT CLAIMED  \
# 0       987884890  NON-ADHERENT      F     30         6800.00
# 1       987953280  NON-ADHERENT      M     90         2654.98
# 2       987996650  NON-ADHERENT      M     60        17640.00
# 3       988899920  NON-ADHERENT      M     60        10654.25
# 4       988828890      ADHERENT      F     60        10654.25
# ...           ...           ...    ...    ...             ...
# 4800    939458560  NON-ADHERENT      M     60         1819.49
# 4801    939828690  NON-ADHERENT      M     15         1050.00
# 4802    948928640  NON-ADHERENT      M     60         4134.43
# 4803    949872540  NON-ADHERENT      M     30          640.00
# 4804    942267480  NON-ADHERENT      M     99         3500.00
#
#             OPTION NAME  AGE SCHEMETYPE COVERTYPE  ANNUALCONTRIBUTION  \
# 0     STUDYMATE PRIVATE   24      BASIC  STANDARD            690384.0
# 1                 ICARE   53     MEDIUM  STANDARD           2718696.0
# ...

# %%
htn['COMORBIDITY'].unique()
# Out:
# array([nan, 'DIABETES'], dtype=object)

# %%
htn.COMORBIDITY = htn.COMORBIDITY.fillna('NO_COMORBIDITY')
htn['COMORBIDITY'].replace({"DIABETES": "COMORBIDITY"}, inplace=True)
diabetes.COMORBIDITY = diabetes.COMORBIDITY.fillna('NO_COMORBIDITY')
diabetes['COMORBIDITY'].replace({"HYPERTENSION": "COMORBIDITY"}, inplace=True)
htn
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\751496259.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   htn['COMORBIDITY'].replace({"DIABETES": "COMORBIDITY"}, inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\751496259.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
htn['COMORBIDITY'].unique()
# Out:
# array(['NO_COMORBIDITY', 'COMORBIDITY'], dtype=object)

# %%
htn['COMORBIDITY'].value_counts()
# Out:
# COMORBIDITY
# NO_COMORBIDITY    15791
# COMORBIDITY        3488
# Name: count, dtype: int64

# %%
diabetes['COMORBIDITY'].unique()
# Out:
# array(['NO_COMORBIDITY', 'COMORBIDITY'], dtype=object)

# %%
diabetes['COMORBIDITY'].value_counts()
# Out:
# COMORBIDITY
# COMORBIDITY       3488
# NO_COMORBIDITY    1317
# Name: count, dtype: int64

# %%
diabetes.columns
# Out:
# Index(['BENEFICIARY', 'ADHERENCE', 'GENDER', 'UNITS', 'AMOUNT CLAIMED',
#        'OPTION NAME', 'AGE', 'SCHEMETYPE', 'COVERTYPE', 'ANNUALCONTRIBUTION',
#        'NEUROLOGY', 'OPTHAMOL', 'PHYSICIAN', 'DIALYSIS',
#        'COMPLICATIONDEVELOPMENT', 'ANNUALCLAIMAMOUNT', 'UNITSTOTAL',
#        'DIAGNOSIS', 'COMORBIDITY'],
#       dtype='object')

# %%
diabetes = diabetes[['ADHERENCE', 'GENDER', 'AGE', 'SCHEMETYPE', 'COVERTYPE', 'ANNUALCONTRIBUTION',
           'COMPLICATIONDEVELOPMENT', 'ANNUALCLAIMAMOUNT', 'UNITSTOTAL',
       'DIAGNOSIS', 'COMORBIDITY']].copy()
diabetes
# Out:
#          ADHERENCE GENDER  AGE SCHEMETYPE COVERTYPE  ANNUALCONTRIBUTION  \
# 0     NON-ADHERENT      F   24      BASIC  STANDARD            690384.0
# 1     NON-ADHERENT      M   53     MEDIUM  STANDARD           2718696.0
# 2     NON-ADHERENT      M   46      BASIC  STANDARD            808284.0
# 3     NON-ADHERENT      M   76      BASIC  STANDARD            808284.0
# 4         ADHERENT      F   69      BASIC  STANDARD            808284.0
# ...            ...    ...  ...        ...       ...                 ...
# 4800  NON-ADHERENT      M   46     MEDIUM  STANDARD           2718696.0
# 4801  NON-ADHERENT      M   54     MEDIUM  STANDARD           2718696.0
# 4802  NON-ADHERENT      M   54    PREMIUM  STANDARD           6889900.0
# 4803  NON-ADHERENT      M   49     MEDIUM  STANDARD           2718696.0
# 4804  NON-ADHERENT      M   36    PREMIUM  STANDARD           6889900.0
#
#      COMPLICATIONDEVELOPMENT  ANNUALCLAIMAMOUNT  UNITSTOTAL DIAGNOSIS  \
# ...

# %%
htn = htn[['ADHERENCE', 'GENDER', 'AGE', 'SCHEMETYPE', 'COVERTYPE', 'ANNUALCONTRIBUTION',
           'COMPLICATIONDEVELOPMENT', 'ANNUALCLAIMAMOUNT', 'UNITSTOTAL',
       'DIAGNOSIS', 'COMORBIDITY']].copy()
htn
# Out:
#           ADHERENCE GENDER  AGE SCHEMETYPE      COVERTYPE  ANNUALCONTRIBUTION  \
# 0      NON-ADHERENT      M   26      BASIC       STANDARD            690384.0
# 1      NON-ADHERENT      F   57      BASIC       STANDARD            690384.0
# 2      NON-ADHERENT      F   37      BASIC       STANDARD            690384.0
# 3      NON-ADHERENT      M   31      BASIC       STANDARD            690384.0
# 4      NON-ADHERENT      M   48      BASIC       STANDARD            690384.0
# ...             ...    ...  ...        ...            ...                 ...
# 19274  NON-ADHERENT      M   50    PREMIUM  COMPREHENSIVE           9724602.0
# 19275  NON-ADHERENT      F   71    PREMIUM  COMPREHENSIVE           9724602.0
# 19276  NON-ADHERENT      M   55    PREMIUM       STANDARD           6889900.0
# 19277      ADHERENT      F   43    PREMIUM       STANDARD           6889900.0
# 19278  NON-ADHERENT      M   65    PREMIUM       STANDARD           6889900.0
#
# ...

# %%
diabetes.columns
# Out:
# Index(['ADHERENCE', 'GENDER', 'AGE', 'SCHEMETYPE', 'COVERTYPE',
#        'ANNUALCONTRIBUTION', 'COMPLICATIONDEVELOPMENT', 'ANNUALCLAIMAMOUNT',
#        'UNITSTOTAL', 'DIAGNOSIS', 'COMORBIDITY'],
#       dtype='object')

# %%
diabetes = diabetes.reindex(columns=['ADHERENCE', 'GENDER', 'SCHEMETYPE', 'DIAGNOSIS', 'COVERTYPE','COMORBIDITY', 
                     'COMPLICATIONDEVELOPMENT','AGE','ANNUALCONTRIBUTION', 'ANNUALCLAIMAMOUNT', 'UNITSTOTAL'])
diabetes
# Out:
#          ADHERENCE GENDER SCHEMETYPE DIAGNOSIS COVERTYPE     COMORBIDITY  \
# 0     NON-ADHERENT      F      BASIC  DIABETES  STANDARD  NO_COMORBIDITY
# 1     NON-ADHERENT      M     MEDIUM  DIABETES  STANDARD  NO_COMORBIDITY
# 2     NON-ADHERENT      M      BASIC  DIABETES  STANDARD     COMORBIDITY
# 3     NON-ADHERENT      M      BASIC  DIABETES  STANDARD     COMORBIDITY
# 4         ADHERENT      F      BASIC  DIABETES  STANDARD     COMORBIDITY
# ...            ...    ...        ...       ...       ...             ...
# 4800  NON-ADHERENT      M     MEDIUM  DIABETES  STANDARD     COMORBIDITY
# 4801  NON-ADHERENT      M     MEDIUM  DIABETES  STANDARD  NO_COMORBIDITY
# 4802  NON-ADHERENT      M    PREMIUM  DIABETES  STANDARD     COMORBIDITY
# 4803  NON-ADHERENT      M     MEDIUM  DIABETES  STANDARD  NO_COMORBIDITY
# 4804  NON-ADHERENT      M    PREMIUM  DIABETES  STANDARD  NO_COMORBIDITY
#
#      COMPLICATIONDEVELOPMENT  AGE  ANNUALCONTRIBUTION  ANNUALCLAIMAMOUNT  \
# ...

# %%
htn = htn.reindex(columns=['ADHERENCE', 'GENDER', 'SCHEMETYPE', 'DIAGNOSIS', 'COVERTYPE','COMORBIDITY', 
                     'COMPLICATIONDEVELOPMENT','AGE','ANNUALCONTRIBUTION', 'ANNUALCLAIMAMOUNT', 'UNITSTOTAL'])
htn
# Out:
#           ADHERENCE GENDER SCHEMETYPE     DIAGNOSIS      COVERTYPE  \
# 0      NON-ADHERENT      M      BASIC  HYPERTENSION       STANDARD
# 1      NON-ADHERENT      F      BASIC  HYPERTENSION       STANDARD
# 2      NON-ADHERENT      F      BASIC  HYPERTENSION       STANDARD
# 3      NON-ADHERENT      M      BASIC  HYPERTENSION       STANDARD
# 4      NON-ADHERENT      M      BASIC  HYPERTENSION       STANDARD
# ...             ...    ...        ...           ...            ...
# 19274  NON-ADHERENT      M    PREMIUM  HYPERTENSION  COMPREHENSIVE
# 19275  NON-ADHERENT      F    PREMIUM  HYPERTENSION  COMPREHENSIVE
# 19276  NON-ADHERENT      M    PREMIUM  HYPERTENSION       STANDARD
# 19277      ADHERENT      F    PREMIUM  HYPERTENSION       STANDARD
# 19278  NON-ADHERENT      M    PREMIUM  HYPERTENSION       STANDARD
#
#           COMORBIDITY COMPLICATIONDEVELOPMENT  AGE  ANNUALCONTRIBUTION  \
# 0      NO_COMORBIDITY         NO_COMPLICATION   26            690384.0
# ...

# %%
# concatenating diabetes and htn along rows
df = pd.concat([diabetes, htn], axis=0)

# %%
df
# Out:
#           ADHERENCE GENDER SCHEMETYPE     DIAGNOSIS      COVERTYPE  \
# 0      NON-ADHERENT      F      BASIC      DIABETES       STANDARD
# 1      NON-ADHERENT      M     MEDIUM      DIABETES       STANDARD
# 2      NON-ADHERENT      M      BASIC      DIABETES       STANDARD
# 3      NON-ADHERENT      M      BASIC      DIABETES       STANDARD
# 4          ADHERENT      F      BASIC      DIABETES       STANDARD
# ...             ...    ...        ...           ...            ...
# 19274  NON-ADHERENT      M    PREMIUM  HYPERTENSION  COMPREHENSIVE
# 19275  NON-ADHERENT      F    PREMIUM  HYPERTENSION  COMPREHENSIVE
# 19276  NON-ADHERENT      M    PREMIUM  HYPERTENSION       STANDARD
# 19277      ADHERENT      F    PREMIUM  HYPERTENSION       STANDARD
# 19278  NON-ADHERENT      M    PREMIUM  HYPERTENSION       STANDARD
#
#           COMORBIDITY COMPLICATIONDEVELOPMENT  AGE  ANNUALCONTRIBUTION  \
# 0      NO_COMORBIDITY         NO_COMPLICATION   24            690384.0
# ...

# %% [raw]
# Data Profilling

# %%
df.isnull().sum()
# Out:
# ADHERENCE                  0
# GENDER                     0
# SCHEMETYPE                 0
# DIAGNOSIS                  0
# COVERTYPE                  0
# COMORBIDITY                0
# COMPLICATIONDEVELOPMENT    0
# AGE                        0
# ANNUALCONTRIBUTION         0
# ANNUALCLAIMAMOUNT          0
# UNITSTOTAL                 0
# dtype: int64

# %%
display(df)
# Out:
#           ADHERENCE GENDER SCHEMETYPE     DIAGNOSIS      COVERTYPE  \
# 0      NON-ADHERENT      F      BASIC      DIABETES       STANDARD
# 1      NON-ADHERENT      M     MEDIUM      DIABETES       STANDARD
# 2      NON-ADHERENT      M      BASIC      DIABETES       STANDARD
# 3      NON-ADHERENT      M      BASIC      DIABETES       STANDARD
# 4          ADHERENT      F      BASIC      DIABETES       STANDARD
# ...             ...    ...        ...           ...            ...
# 19274  NON-ADHERENT      M    PREMIUM  HYPERTENSION  COMPREHENSIVE
# 19275  NON-ADHERENT      F    PREMIUM  HYPERTENSION  COMPREHENSIVE
# 19276  NON-ADHERENT      M    PREMIUM  HYPERTENSION       STANDARD
# 19277      ADHERENT      F    PREMIUM  HYPERTENSION       STANDARD
# 19278  NON-ADHERENT      M    PREMIUM  HYPERTENSION       STANDARD
#
#           COMORBIDITY COMPLICATIONDEVELOPMENT  AGE  ANNUALCONTRIBUTION  \
# 0      NO_COMORBIDITY         NO_COMPLICATION   24            690384.0
# ...

# %%
df.columns
# Out:
# Index(['ADHERENCE', 'GENDER', 'SCHEMETYPE', 'DIAGNOSIS', 'COVERTYPE',
#        'COMORBIDITY', 'COMPLICATIONDEVELOPMENT', 'AGE', 'ANNUALCONTRIBUTION',
#        'ANNUALCLAIMAMOUNT', 'UNITSTOTAL'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24084 entries, 0 to 19278
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ADHERENCE                24084 non-null  category
#  1   GENDER                   24084 non-null  object
#  2   SCHEMETYPE               24084 non-null  object
#  3   DIAGNOSIS                24084 non-null  object
#  4   COVERTYPE                24084 non-null  object
#  5   COMORBIDITY              24084 non-null  object
#  6   COMPLICATIONDEVELOPMENT  24084 non-null  object
#  7   AGE                      24084 non-null  int64
#  8   ANNUALCONTRIBUTION       24084 non-null  float64
#  9   ANNUALCLAIMAMOUNT        24084 non-null  float64
#  10  UNITSTOTAL               24084 non-null  float64
# dtypes: category(1), float64(3), int64(1), object(6)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#                 AGE  ANNUALCONTRIBUTION  ANNUALCLAIMAMOUNT    UNITSTOTAL
# count  24084.000000        2.408400e+04       2.408400e+04  2.408400e+04
# mean      56.579762        5.993621e+06       6.579390e+05  2.862657e+03
# std       14.479047        2.291566e+06       6.127169e+07  1.722682e+05
# min       16.000000        2.117640e+05       9.900000e-01  1.000000e+00
# 25%       46.000000        2.718696e+06       1.230677e+04  1.200000e+02
# 50%       56.000000        6.889900e+06       4.043974e+04  3.440000e+02
# 75%       66.000000        6.889900e+06       1.020879e+05  7.200000e+02
# max      103.000000        1.177079e+07       9.401312e+09  2.129064e+07

# %%
df.shape
# Out:
# (24084, 11)

# %%
df.columns
# Out:
# Index(['ADHERENCE', 'GENDER', 'SCHEMETYPE', 'DIAGNOSIS', 'COVERTYPE',
#        'COMORBIDITY', 'COMPLICATIONDEVELOPMENT', 'AGE', 'ANNUALCONTRIBUTION',
#        'ANNUALCLAIMAMOUNT', 'UNITSTOTAL'],
#       dtype='object')

# %%
df['ADHERENCE'].unique()
# Out:
# ['NON-ADHERENT', 'ADHERENT']
# Categories (2, object): ['NON-ADHERENT' < 'ADHERENT']

# %%
df.ADHERENCE= df.ADHERENCE.fillna('NON-ADHERENT')

# %%
df['ADHERENCE'].value_counts()
# Out:
# ADHERENCE
# NON-ADHERENT    14415
# ADHERENT         9669
# Name: count, dtype: int64

# %%
pd.crosstab(index=df['ADHERENCE'], columns='Frequency Count')
# Out:
# col_0         Frequency Count
# ADHERENCE
# NON-ADHERENT            14415
# ADHERENT                 9669

# %%
pd.crosstab(index=df['GENDER'], columns='Frequency Count')
# Out:
# col_0   Frequency Count
# GENDER
# F                 11013
# M                 13071

# %%
pd.crosstab(index=df['DIAGNOSIS'], columns='Frequency Count')
# Out:
# col_0         Frequency Count
# DIAGNOSIS
# DIABETES                 4805
# HYPERTENSION            19279

# %%
pd.crosstab(index=df['SCHEMETYPE'], columns='Frequency Count')
# Out:
# col_0       Frequency Count
# SCHEMETYPE
# BASIC                  1043
# MEDIUM                 5148
# PREMIUM               17893

# %%
pd.crosstab(index=df['COVERTYPE'], columns='Frequency Count')
# Out:
# col_0          Frequency Count
# COVERTYPE
# COMPREHENSIVE             4810
# STANDARD                 19274

# %%
pd.crosstab(index=df['COMORBIDITY'], columns='Frequency Count')
# Out:
# col_0           Frequency Count
# COMORBIDITY
# COMORBIDITY                6976
# NO_COMORBIDITY            17108

# %%
pd.crosstab(index=df['COMPLICATIONDEVELOPMENT'], columns='Frequency Count')
# Out:
# col_0                    Frequency Count
# COMPLICATIONDEVELOPMENT
# COMPLICATION                        2311
# NO_COMPLICATION                    21773

# %%
pd.crosstab(df['ADHERENCE'], df['DIAGNOSIS'])
# Out:
# DIAGNOSIS     DIABETES  HYPERTENSION
# ADHERENCE
# NON-ADHERENT      2697         11718
# ADHERENT          2108          7561

# %%
pd.crosstab(df['ADHERENCE'], df['GENDER'])
# Out:
# GENDER           F     M
# ADHERENCE
# NON-ADHERENT  6413  8002
# ADHERENT      4600  5069

# %%
df.mode()
# Out:
#       ADHERENCE GENDER SCHEMETYPE     DIAGNOSIS COVERTYPE     COMORBIDITY  \
# 0  NON-ADHERENT      M    PREMIUM  HYPERTENSION  STANDARD  NO_COMORBIDITY
#
#   COMPLICATIONDEVELOPMENT  AGE  ANNUALCONTRIBUTION  ANNUALCLAIMAMOUNT  \
# 0         NO_COMPLICATION   53           6889900.0             6000.0
#
#    UNITSTOTAL
# 0        30.0

# %%
df.columns
# Out:
# Index(['ADHERENCE', 'GENDER', 'SCHEMETYPE', 'DIAGNOSIS', 'COVERTYPE',
#        'COMORBIDITY', 'COMPLICATIONDEVELOPMENT', 'AGE', 'ANNUALCONTRIBUTION',
#        'ANNUALCLAIMAMOUNT', 'UNITSTOTAL'],
#       dtype='object')

# %% [raw]
# Variable Encoding# Categorical Variables

# %%
df= pd.get_dummies(df, columns=['GENDER', 'SCHEMETYPE', 'DIAGNOSIS', 'COVERTYPE', 'COMORBIDITY', 'COMPLICATIONDEVELOPMENT'], drop_first=True)

# %%
df
# Out:
#           ADHERENCE  AGE  ANNUALCONTRIBUTION  ANNUALCLAIMAMOUNT  UNITSTOTAL  \
# 0      NON-ADHERENT   24            690384.0           10400.00        60.0
# 1      NON-ADHERENT   53           2718696.0          306366.53      1380.0
# 2      NON-ADHERENT   46            808284.0           77480.00       600.0
# 3      NON-ADHERENT   76            808284.0          198800.58       840.0
# 4          ADHERENT   69            808284.0          116872.04       720.0
# ...             ...  ...                 ...                ...         ...
# 19274  NON-ADHERENT   50           9724602.0            3500.00        30.0
# 19275  NON-ADHERENT   71           9724602.0            4763.96        30.0
# 19276  NON-ADHERENT   55           6889900.0            3899.19        30.0
# 19277      ADHERENT   43           6889900.0               4.13        30.0
# 19278  NON-ADHERENT   65           6889900.0            4638.34        60.0
#
# ...

# %%
scaled_features = df.copy()

# %%
scaled_features.columns
# Out:
# Index(['ADHERENCE', 'AGE', 'ANNUALCONTRIBUTION', 'ANNUALCLAIMAMOUNT',
#        'UNITSTOTAL', 'GENDER_M', 'SCHEMETYPE_MEDIUM', 'SCHEMETYPE_PREMIUM',
#        'DIAGNOSIS_HYPERTENSION', 'COVERTYPE_STANDARD',
#        'COMORBIDITY_NO_COMORBIDITY',
#        'COMPLICATIONDEVELOPMENT_NO_COMPLICATION'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
col_names = ['AGE', 'ANNUALCONTRIBUTION', 'ANNUALCLAIMAMOUNT', 'UNITSTOTAL']
features = scaled_features[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)

# %%
features
# Out:
# array([[-2.25017837, -2.31428983, -0.01056854, -0.01626948],
#        [-0.24724257, -1.4291509 , -0.00573805, -0.00860685],
#        [-0.73070983, -2.26283922, -0.00947372, -0.01313477],
#        ...,
#        [-0.10910906,  0.39112873, -0.01067464, -0.01644363],
#        [-0.93791008,  0.39112873, -0.01073821, -0.01644363],
#        [ 0.58155845,  0.39112873, -0.01066258, -0.01626948]],
#       shape=(24084, 4))

# %%
scaled_features[col_names] = features
scaled_features
# Out:
#           ADHERENCE       AGE  ANNUALCONTRIBUTION  ANNUALCLAIMAMOUNT  \
# 0      NON-ADHERENT -2.250178           -2.314290          -0.010569
# 1      NON-ADHERENT -0.247243           -1.429151          -0.005738
# 2      NON-ADHERENT -0.730710           -2.262839          -0.009474
# 3      NON-ADHERENT  1.341293           -2.262839          -0.007494
# 4          ADHERENT  0.857825           -2.262839          -0.008831
# ...             ...       ...                 ...                ...
# 19274  NON-ADHERENT -0.454443            1.628170          -0.010681
# 19275  NON-ADHERENT  0.995959            1.628170          -0.010661
# 19276  NON-ADHERENT -0.109109            0.391129          -0.010675
# 19277      ADHERENT -0.937910            0.391129          -0.010738
# 19278  NON-ADHERENT  0.581558            0.391129          -0.010663
#
#        UNITSTOTAL  GENDER_M  SCHEMETYPE_MEDIUM  SCHEMETYPE_PREMIUM  \
# 0       -0.016269     False              False               False
# ...

# %%
scaled_features.max(axis=0)
# Out:
# ADHERENCE                                   ADHERENT
# AGE                                         3.206095
# ANNUALCONTRIBUTION                          2.521109
# ANNUALCLAIMAMOUNT                          153.42893
# UNITSTOTAL                                 123.57602
# GENDER_M                                        True
# SCHEMETYPE_MEDIUM                               True
# SCHEMETYPE_PREMIUM                              True
# DIAGNOSIS_HYPERTENSION                          True
# COVERTYPE_STANDARD                              True
# COMORBIDITY_NO_COMORBIDITY                      True
# COMPLICATIONDEVELOPMENT_NO_COMPLICATION         True
# dtype: object

# %%
scaled_features.min(axis=0)
# Out:
# ADHERENCE                                  NON-ADHERENT
# AGE                                           -2.802712
# ANNUALCONTRIBUTION                            -2.523156
# ANNUALCLAIMAMOUNT                             -0.010738
# UNITSTOTAL                                    -0.016612
# GENDER_M                                          False
# SCHEMETYPE_MEDIUM                                 False
# SCHEMETYPE_PREMIUM                                False
# DIAGNOSIS_HYPERTENSION                            False
# COVERTYPE_STANDARD                                False
# COMORBIDITY_NO_COMORBIDITY                        False
# COMPLICATIONDEVELOPMENT_NO_COMPLICATION           False
# dtype: object

# %% [raw]
# Feature Importance using the RF Feature Importance Scores

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Independent Variables
X=df[['AGE', 'ANNUALCONTRIBUTION', 'ANNUALCLAIMAMOUNT', 'UNITSTOTAL', 'GENDER_M', 'SCHEMETYPE_MEDIUM', 'SCHEMETYPE_PREMIUM',
       'DIAGNOSIS_HYPERTENSION', 'COVERTYPE_STANDARD', 'COMORBIDITY_NO_COMORBIDITY', 'COMPLICATIONDEVELOPMENT_NO_COMPLICATION']]
X
# Out:
#        AGE  ANNUALCONTRIBUTION  ANNUALCLAIMAMOUNT  UNITSTOTAL  GENDER_M  \
# 0       24            690384.0           10400.00        60.0     False
# 1       53           2718696.0          306366.53      1380.0      True
# 2       46            808284.0           77480.00       600.0      True
# 3       76            808284.0          198800.58       840.0      True
# 4       69            808284.0          116872.04       720.0     False
# ...    ...                 ...                ...         ...       ...
# 19274   50           9724602.0            3500.00        30.0      True
# 19275   71           9724602.0            4763.96        30.0     False
# 19276   55           6889900.0            3899.19        30.0      True
# 19277   43           6889900.0               4.13        30.0     False
# 19278   65           6889900.0            4638.34        60.0      True
#
#        SCHEMETYPE_MEDIUM  SCHEMETYPE_PREMIUM  DIAGNOSIS_HYPERTENSION  \
# ...

# %%
# Dependent Variable
y=df['ADHERENCE']
y
# Out:
# 0        NON-ADHERENT
# 1        NON-ADHERENT
# 2        NON-ADHERENT
# 3        NON-ADHERENT
# 4            ADHERENT
#              ...
# 19274    NON-ADHERENT
# 19275    NON-ADHERENT
# 19276    NON-ADHERENT
# 19277        ADHERENT
# 19278    NON-ADHERENT
# Name: ADHERENCE, Length: 24084, dtype: category
# Categories (2, object): ['NON-ADHERENT' < 'ADHERENT']

# %%
# Splitting the Dataset into Training and Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (24084, 11)
# (16858, 11)
# (7226, 11)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score
lr_filtered = LogisticRegression(max_iter=1000)
lr_filtered.fit(X_train, y_train)

# Predict and evaluate
y_pred_lr = lr_filtered.predict(X_test)
print("Logistic Regression Performance")
print(classification_report(y_test, y_pred_lr))
print("ROC-AUC:", roc_auc_score(y_test, lr_filtered.predict_proba(X_test)[:,1]))
# Out:
# Logistic Regression Performance
#               precision    recall  f1-score   support
#
#     ADHERENT       0.41      0.17      0.24      2880
# NON-ADHERENT       0.60      0.84      0.70      4346
#
#     accuracy                           0.57      7226
#    macro avg       0.51      0.50      0.47      7226
# weighted avg       0.53      0.57      0.52      7226
#
# ROC-AUC: 0.5533999974433707

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred_lr)
# Out:
# 0.5722391364517022

# %%
# Fitting a random forest classifier
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=1, max_depth = 7, n_estimators = 200, criterion = "entropy")
clf = clf.fit(X_train, y_train)

# %%
clf_0 = clf.estimators_[0]
clf_0
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features='sqrt',
#                        random_state=1791095845)

# %%
# Model Prediction
# generating predictions
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.8081926376972045

# %%
# Feature Impportance
df_feature_importance = pd.DataFrame(clf.feature_importances_, index = X.columns, columns = ["Feature Score"])

# sort values into descending order
df_feature_importance.sort_values(by = "Feature Score", ascending=False, inplace = True)

df_feature_importance
# Out:
#                                          Feature Score
# UNITSTOTAL                                    0.583893
# ANNUALCLAIMAMOUNT                             0.315817
# AGE                                           0.051605
# COMPLICATIONDEVELOPMENT_NO_COMPLICATION       0.012950
# COMORBIDITY_NO_COMORBIDITY                    0.010350
# DIAGNOSIS_HYPERTENSION                        0.009693
# ANNUALCONTRIBUTION                            0.007872
# GENDER_M                                      0.003058
# COVERTYPE_STANDARD                            0.001810
# SCHEMETYPE_PREMIUM                            0.001733
# SCHEMETYPE_MEDIUM                             0.001219

# %%
model_ranks=pd.Series(clf.feature_importances_,index=X_train.columns,name="Importance").sort_values(ascending=True, inplace=False)
ax=model_ranks.plot(kind='barh')

# %%
# Keep only features with importance > 0.005
important_features = [
    'UNITSTOTAL',
    'ANNUALCLAIMAMOUNT',
    'AGE',
    'COMPLICATIONDEVELOPMENT_NO_COMPLICATION',
    'COMORBIDITY_NO_COMORBIDITY',
    'DIAGNOSIS_HYPERTENSION',
    'ANNUALCONTRIBUTION'
]

# %%
# Select only the important features
X_train_filtered = X_train[important_features]
X_test_filtered = X_test[important_features]

# %%
lr_filtered = LogisticRegression(max_iter=1000)
lr_filtered.fit(X_train_filtered, y_train)

# Predict and evaluate
y_pred_lr_filtered = lr_filtered.predict(X_test_filtered)
print("Logistic Regression (Filtered Features)")
print(classification_report(y_test, y_pred_lr_filtered))
print("ROC-AUC:", roc_auc_score(y_test, lr_filtered.predict_proba(X_test_filtered)[:,1]))
# Out:
# Logistic Regression (Filtered Features)
#               precision    recall  f1-score   support
#
#     ADHERENT       0.41      0.17      0.24      2880
# NON-ADHERENT       0.60      0.84      0.70      4346
#
#     accuracy                           0.57      7226
#    macro avg       0.51      0.50      0.47      7226
# weighted avg       0.53      0.57      0.52      7226
#
# ROC-AUC: 0.5529549042542312

# %%
clf_adv = RandomForestClassifier(random_state=1, max_depth = 7, n_estimators = 200, criterion = "entropy")
clf_adv = clf_adv.fit(X_train_filtered, y_train)

# %%
clf_adv_0 = clf.estimators_[0]
clf_adv_0
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features='sqrt',
#                        random_state=1791095845)

# %%
# Model Prediction
# generating predictions
Y_pred_rf_filtered = clf_adv.predict(X_test_filtered)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, Y_pred_rf_filtered)
# Out:
# 0.808746194298367

# %%
# More precise feature importance
df_precise_feature_importance = pd.DataFrame(
    clf_adv.feature_importances_,
    index = X_train_filtered.columns,
    columns = ["Feature Score"]
)

# Sort values in descending order
df_precise_feature_importance.sort_values(by="Feature Score", ascending=False, inplace=True)

# Display
df_precise_feature_importance
# Out:
#                                          Feature Score
# UNITSTOTAL                                    0.559448
# ANNUALCLAIMAMOUNT                             0.337107
# AGE                                           0.059432
# COMPLICATIONDEVELOPMENT_NO_COMPLICATION       0.012077
# COMORBIDITY_NO_COMORBIDITY                    0.011902
# ANNUALCONTRIBUTION                            0.010542
# DIAGNOSIS_HYPERTENSION                        0.009492

# %%
from sklearn.metrics import roc_auc_score

# Predict probabilities for the positive class (class 1)
y_probs_rf = clf_adv.predict_proba(X_test_filtered)[:, 1]

# Calculate ROC-AUC score
roc_auc_rf = roc_auc_score(y_test, y_probs_rf)

# Print the result
print("Random Forest ROC-AUC:", roc_auc_rf)
# Out:
# Random Forest ROC-AUC: 0.8935628866901877

# %%
# Create a pandas Series for feature importances
model_ranks = pd.Series(clf_adv.feature_importances_, index=X_train_filtered.columns, name="Importance").sort_values(ascending=True, inplace=False)

# Plot the feature importances as a horizontal bar chart
ax = model_ranks.plot(kind='barh', figsize=(10,6), color='lightcoral')
plt.title('Feature Importances - Random Forest')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'ADHERENCE' column is your target
sns.countplot(x='ADHERENCE', data=diabetes, palette='Set2')
plt.title('Adherence Distribution')
plt.xlabel('Adherence Status')
plt.ylabel('Number of Patients')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\2678829285.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ADHERENCE', data=diabetes, palette='Set2')

# %%
sns.histplot(data=diabetes, x='AGE', kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x='ADHERENCE', y='AGE', data=diabetes, palette='coolwarm')
plt.title('Adherence vs Age')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\916493326.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='ADHERENCE', y='AGE', data=diabetes, palette='coolwarm')

# %%
from sklearn.preprocessing import LabelEncoder

# Convert 'ADHERENT' → 1 and 'NON-ADHERENT' → 0
le = LabelEncoder()
y_test_encoded = le.fit_transform(y_test)

# %%
# Logistic Regression
y_probs_lr = lr_filtered.predict_proba(X_test_filtered)[:,1]
fpr_lr, tpr_lr, _ = roc_curve(y_test_encoded, y_probs_lr)
auc_lr = auc(fpr_lr, tpr_lr)

# Random Forest
y_probs_rf = clf_adv.predict_proba(X_test_filtered)[:,1]
fpr_rf, tpr_rf, _ = roc_curve(y_test_encoded, y_probs_rf)
auc_rf = auc(fpr_rf, tpr_rf)

# Plot both
plt.figure(figsize=(8,6))
plt.plot(fpr_lr, tpr_lr, label='Logistic Regression (AUC = %0.2f)' % auc_lr)
plt.plot(fpr_rf, tpr_rf, label='Random Forest (AUC = %0.2f)' % auc_rf)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# Save image
plt.savefig("roc_curve.png")
plt.close()

# %%
# Example: Add predictions to test data
X_test_with_preds = X_test_filtered.copy()
X_test_with_preds['Actual_Adherence'] = y_test  # Actual labels
X_test_with_preds['Predicted_Probability'] = lr_filtered.predict_proba(X_test_filtered)[:,1]
X_test_with_preds['Predicted_Class'] = lr_filtered.predict(X_test_filtered)

# Export to CSV
X_test_with_preds.to_csv("model_predictions.csv", index=False)

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train_filtered.columns,
    'Importance': clf_adv.feature_importances_
})

feature_importance.sort_values(by='Importance', ascending=False, inplace=True)
feature_importance.to_csv("feature_scores.csv", index=False)

# %%
summary = diabetes.groupby(['ADHERENCE', 'GENDER']).size().reset_index(name='Count')
summary.to_csv("adherence_by_gender.csv", index=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11840\4213009806.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = diabetes.groupby(['ADHERENCE', 'GENDER']).size().reset_index(name='Count')

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, lr_filtered.predict(X_test_filtered))
cm_df = pd.DataFrame(cm, columns=["Predicted_NonAdherent", "Predicted_Adherent"],
                          index=["Actual_NonAdherent", "Actual_Adherent"])

cm_df.to_csv("confusion_matrix.csv")
